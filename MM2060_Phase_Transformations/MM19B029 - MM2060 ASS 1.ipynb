# %% [markdown]
# #### CHIRANTANDIP MAHANTA  MM19B029

# %% [markdown]
# # Q1 Ans:

# %%
DATA = [["%C","%Cr","UTS","YS","EL","Name"],
        [0.02, 20  , 90  , 65 ,25  ,"19D SS"],
        [0.07, 14  ,200  ,185 , 9  ,"15-5PH (H900)"],
        [0.15, 13  , 85  , 45 ,25  ,"Type 420 LC"],
        [0.03, 18.5, 71  , 45 ,32  ,"Type 441"],
        [0.15, 17  ,120  , 45 ,60  ,"Type 301"]]
Markers = ['o','D','*','^','s']

# %%
UTS_C = Graphics()
for i in range(1,6):
    UTS_C += point([DATA[i][0],DATA[i][2]],
                   marker=Markers[i-1],size=30,color='red',
                   legend_label=DATA[i][5],
                  axes_labels=['%C','UTS(MPa)'])

# %%
UTS_Cr = Graphics()
for i in range(1,6):
    UTS_Cr += point([DATA[i][1],DATA[i][2]],
                   marker=Markers[i-1],size=30,color='red',
                   legend_label=DATA[i][5],
                   axes_labels=['%Cr','UTS(MPa)'])

# %%
YS_C = Graphics()
for i in range(1,6):
    YS_C += point([DATA[i][0],DATA[i][3]],
                   marker=Markers[i-1],size=30,color='red',
                   legend_label=DATA[i][5],
                 axes_labels=['%C','0.2%YS(MPa)'])

# %%
YS_Cr = Graphics()
for i in range(1,6):
    YS_Cr += point([DATA[i][1],DATA[i][3]],
                   marker=Markers[i-1],size=30,color='red',
                   legend_label=DATA[i][5],
                  axes_labels=['%Cr','0.2%YS(MPa)'])

# %%
EL_C = Graphics()
for i in range(1,6):
    EL_C += point([DATA[i][0],DATA[i][4]],
                   marker=Markers[i-1],size=30,color='red',
                   legend_label=DATA[i][5],
                 axes_labels=['%C','%elongation % in 2\"'])

# %%
EL_Cr = Graphics()
for i in range(1,6):
    EL_Cr += point([DATA[i][1],DATA[i][4]],
                   marker=Markers[i-1],size=30,color='red',
                   legend_label=DATA[i][5],
                  axes_labels=['%Cr','%elongation % in 2\"'])

# %%
ALL_plots = graphics_array([[UTS_C,UTS_Cr],[YS_C,YS_Cr],[EL_C,EL_Cr]])

# %%
ALL_plots.show(figsize=(12,12))
# Out:
# Graphics Array of size 3 x 2

# %% [markdown]
# # Q2 Ans:

# %% [markdown]
# Neither UTS nor YS or Elongation depends on $\%C$ or $\%Cr$ **alone**. These properties also depend on processes carried out.  Also _precipitation hardening_ seems to have a significant effect in increasing the UTS ans YS of the steel.

# %% [markdown]
# # Q3 Ans:

# %% [markdown]
# **15-5PH (H900)** steel has the heighest YS of $185MPa$.$$ $$ And the largest elongation is in **Type 301** Steel.

# %% [markdown]
# # Q4 Ans:

# %% [markdown]
# Low temperature phase.
